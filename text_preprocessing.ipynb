# %%
import nltk
import warnings
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# load filtered df

filtered_df = pd.read_pickle('data/filtered_df.pkl')

# %%
filtered_df.head()
# Out:
#          id                                              title  \
# 5    927358                   How do you undo the last commit?
# 11   179123            Edit an incorrect commit message in Git
# 12  2003505      Delete a Git branch both locally and remotely
# 23   292357  What are the differences between 'git pull' an...
# 24   111102                   How do JavaScript closures work?
#
#                                                  body        tags
# 5   I committed the wrong files to Git. How can I ...         git
# 11  I wrote the wrong thing in a commit message. H...         git
# 12  I want to delete a branch both locally and on ...         git
# 23  What are the differences between git pull and ...         git
# 24  How would you explain JavaScript closures to s...  javascript

# %% [markdown]
# ### preprocesss:
# * converting all letters to lower or upper case
# * converting numbers into words or removing numbers
# * removing white spaces
# * removing punctuations, accent marks and other diacritics

# %%
def text_preprocess(text):
    '''
    input:
    post: a string with symbols and punctuations 
    returns:
    cleaned post with all letters to lower, all numbers, white space, and symbols removed
    '''
    pattern = r'[^A-Za-z]+'  # anything that is not letter or space
    processed = re.sub(pattern, ' ', text).strip().lower()
    return processed

# %%
# clean up the text column for text_target
filtered_df['cleaned_body'] = filtered_df.body.apply(text_preprocess)

# %%
filtered_df.loc[:,['body','cleaned_body']].head()
# Out:
#                                                  body  \
# 5   I committed the wrong files to Git. How can I ...
# 11  I wrote the wrong thing in a commit message. H...
# 12  I want to delete a branch both locally and on ...
# 23  What are the differences between git pull and ...
# 24  How would you explain JavaScript closures to s...
#
#                                          cleaned_body
# 5   i committed the wrong files to git how can i u...
# 11  i wrote the wrong thing in a commit message ho...
# 12  i want to delete a branch both locally and on ...
# 23  what are the differences between git pull and ...
# 24  how would you explain javascript closures to s...

# %% [markdown]
# ## tokenize and lemmatize
# * removing stop words, sparse terms, and particular words
# * lemmatization

# %%
# position tags function to word_net postition tag
def get_wordnet_pos(treebank_tag):
    '''
    input: 
    treebank_tag: position tag from treebank_tag from nltk.pos_tag output
    output:
    return:
    wordnet position tag 
    '''
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return

# %%
lemmatizer = WordNetLemmatizer()


def token_lemma(text):
    '''
    input:
    post: cleaned post from function text_preprocess
    returns:
    tokenized post with lemmatization with position tags
    stopwords and tags are removed 
    '''
    tokens = word_tokenize(text)
    # stopwords
    stop_words = set(stopwords.words('english'))  # make sure no repeats
    # remove stopwords and remove words that are explicit tags
    words_to_remove = set(filtered_df.tags.unique()).union(stop_words)
    # perform pos tag before stop word removal to include more context for pos tags
    tags = nltk.pos_tag(tokens)
    tags_word_net = [get_wordnet_pos(w[1]) for w in tags]
    lem_result = []  # only include nonstop words and target tags
    for i in range(len(tags_word_net)):
        if tags[i][0] in words_to_remove:  # don't lemmatize unneeded words
            continue
        if tags_word_net[i]:  # not none
            lem_result.append(lemmatizer.lemmatize(
                tags[i][0], tags_word_net[i]))
        else:
            lem_result.append(tags[i][0])
    return lem_result

# %%
# apply to text to tokenize and lemmatize
filtered_df['tokens'] = filtered_df.cleaned_body.apply(token_lemma)

# %%
filtered_df.head()
# Out:
#          id                                              title  \
# 5    927358                   How do you undo the last commit?
# 11   179123            Edit an incorrect commit message in Git
# 12  2003505      Delete a Git branch both locally and remotely
# 23   292357  What are the differences between 'git pull' an...
# 24   111102                   How do JavaScript closures work?
#
#                                                  body        tags  \
# 5   I committed the wrong files to Git. How can I ...         git
# 11  I wrote the wrong thing in a commit message. H...         git
# 12  I want to delete a branch both locally and on ...         git
# 23  What are the differences between git pull and ...         git
# 24  How would you explain JavaScript closures to s...  javascript
#
#                                          cleaned_body  \
# 5   i committed the wrong files to git how can i u...
# 11  i wrote the wrong thing in a commit message ho...
# 12  i want to delete a branch both locally and on ...
# 23  what are the differences between git pull and ...
# 24  how would you explain javascript closures to s...
#
#                                                tokens
# 5                 [commit, wrong, file, undo, commit]
# 11  [write, wrong, thing, commit, message, change,...
# 12  [want, delete, branch, locally, remote, projec...
# 23                          [difference, pull, fetch]
# 24  [would, explain, closure, someone, knowledge, ...

# %%
# join the tokens into cleaned_text for feature engineering later
filtered_df['cleaned_body'] = filtered_df.tokens.apply(lambda x: ' '.join(x))

# %%
filtered_df.head()
# Out:
#          id                                              title  \
# 5    927358                   How do you undo the last commit?
# 11   179123            Edit an incorrect commit message in Git
# 12  2003505      Delete a Git branch both locally and remotely
# 23   292357  What are the differences between 'git pull' an...
# 24   111102                   How do JavaScript closures work?
#
#                                                  body        tags  \
# 5   I committed the wrong files to Git. How can I ...         git
# 11  I wrote the wrong thing in a commit message. H...         git
# 12  I want to delete a branch both locally and on ...         git
# 23  What are the differences between git pull and ...         git
# 24  How would you explain JavaScript closures to s...  javascript
#
#                                          cleaned_body  \
# 5                       commit wrong file undo commit
# 11  write wrong thing commit message change messag...
# 12  want delete branch locally remote project fork...
# 23                              difference pull fetch
# 24  would explain closure someone knowledge concep...
#
#                                                tokens
# 5                 [commit, wrong, file, undo, commit]
# 11  [write, wrong, thing, commit, message, change,...
# 12  [want, delete, branch, locally, remote, projec...
# 23                          [difference, pull, fetch]
# 24  [would, explain, closure, someone, knowledge, ...

# %%
# save the data to a pickle file
filtered_df.to_pickle('data/cleaned_body.pkl')

# %%
pd.read_pickle('data/cleaned_body.pkl')
# Out:
#               id                                              title  \
# 5         927358                   How do you undo the last commit?
# 11        179123            Edit an incorrect commit message in Git
# 12       2003505      Delete a Git branch both locally and remotely
# 23        292357  What are the differences between 'git pull' an...
# 24        111102                   How do JavaScript closures work?
# ...          ...                                                ...
# 249970   8744162  Difference between returning null and from a J...
# 249971  16988597      Set drag margin for Android Navigation Drawer
# 249972   7576525             Optional stdin in Python with argparse
# 249973   8601831  Do not use System.out.println in server side code
# 249974  15322556               How to remove an attribute in D3.js?
#
#                                                      body        tags  \
# 5       I committed the wrong files to Git. How can I ...         git
# 11      I wrote the wrong thing in a commit message. H...         git
# 12      I want to delete a branch both locally and on ...         git
# 23      What are the differences between git pull and ...         git
# 24      How would you explain JavaScript closures to s...  javascript
# ...                                                   ...         ...
# 249970  From what I understand when a JSF action retur...        java
# 249971  I am using the new Navigation Drawer in my app...     android
# 249972  I found the very useful syntax parser.add_argu...      python
# 249973  I heard that using System.out.println for logg...        java
# 249974  Can I in D3.JS remove an attribute? I've added...  javascript
#
#                                              cleaned_body  \
# 5                           commit wrong file undo commit
# 11      write wrong thing commit message change messag...
# 12      want delete branch locally remote project fork...
# 23                                  difference pull fetch
# 24      would explain closure someone knowledge concep...
# ...                                                   ...
# 249970  understand jsf action return empty string user...
# 249971  use new navigation drawer app great except fin...
# 249972  find useful syntax parser add argument input f...
# 249973  hear use system println log purpose bad practi...
# 249974  j remove attribute add use attr disable disabl...
#
#                                                    tokens
# 5                     [commit, wrong, file, undo, commit]
# 11      [write, wrong, thing, commit, message, change,...
# 12      [want, delete, branch, locally, remote, projec...
# 23                              [difference, pull, fetch]
# 24      [would, explain, closure, someone, knowledge, ...
# ...                                                   ...
# 249970  [understand, jsf, action, return, empty, strin...
# 249971  [use, new, navigation, drawer, app, great, exc...
# 249972  [find, useful, syntax, parser, add, argument, ...
# 249973  [hear, use, system, println, log, purpose, bad...
# 249974  [j, remove, attribute, add, use, attr, disable...
#
# [41752 rows x 6 columns]
